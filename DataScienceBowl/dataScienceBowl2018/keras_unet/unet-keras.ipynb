# %%
import os
import sys
import random 
import warnings
import re

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from PIL import Image
from scipy.misc import imfilter
from sklearn.model_selection import train_test_split

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from keras.losses import binary_crossentropy

import tensorflow as tf
# %matplotlib inline

########## This code is revised from https://www.kaggle.com/keegil/keras-u-net-starter-lb-0-277 ##########

# Set some parameters
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3  # training set has 4 channels, but testing set only has 3 channels
BATCH_SIZE = 8
train_on_local = True
if train_on_local:
    TRAIN_PATH = '/home/liming/Documents/dataset/dataScienceBowl2018/stage1_train/'
    TEST_PATH = '/home/liming/Documents/dataset/dataScienceBowl2018/stage1_test/'
else:
    TRAIN_PATH = '/home/PNW/wu1114/Documents/dataset/dataScienceBowl2018/stage1_train/'
    TEST_PATH = '/home/PNW/wu1114/Documents/dataset/dataScienceBowl2018/stage1_test/'
warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
# random.seed = seed
# np.random.seed = seed
# Out:
# /home/liming/anaconda3/envs/tf/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def assemble_masks(path):
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH), dtype=np.bool)
    for mask_file in next(os.walk(os.path.join(path, 'masks')))[2]:
        mask_ = Image.open(os.path.join(path, 'masks', mask_file))
        mask_ = mask_.resize((IMG_HEIGHT, IMG_WIDTH))
        mask_ = np.asarray(mask_, dtype = np.bool)
        mask = mask | mask_
    mask = np.expand_dims(mask, axis=-1)
    return mask

# %%
def prepare_data(TRAIN_PATH, TEST_PATH):
    '''
    Args:
        file_dir: root file directory
    Returns:
        list of training images, in ndarray, e.g. (560,256,256,4)
        list of training labels, in ndarray, e.g. (560,256,256,1)
    '''
    # get imageId
    train_ids = next(os.walk(TRAIN_PATH))[1]
    test_ids = next(os.walk(TEST_PATH))[1]

    # read training data
    X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
    Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    print('reading training data...')
    sys.stdout.flush()
    for n, id_ in tqdm(enumerate(train_ids)):
        path = os.path.join(TRAIN_PATH + id_)
        img = Image.open(os.path.join(path, 'images', id_ + '.png')).convert("RGB")
        img = img.resize((IMG_HEIGHT, IMG_WIDTH))
        X_train[n] = img
        Y_train[n] = assemble_masks(path)
    
    # read testing data        
    sizes_test = []
    X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
    print('reading testing data')
    sys.stdout.flush()
    for n, id_ in tqdm(enumerate(test_ids)):
        path = os.path.join(TEST_PATH, id_, 'images', id_ + '.png')
        img = Image.open(path).convert("RGB")
        sizes_test.append(img.size)
        img = img.resize((IMG_HEIGHT, IMG_WIDTH))
        X_test[n] = img
    print('done')
    return X_train, Y_train, X_test, sizes_test, train_ids, test_ids

# %%
X_train, Y_train, X_test, sizes_test, train_ids, test_ids = prepare_data(TRAIN_PATH, TEST_PATH)
# Out:
# reading training data...
# 670it [00:23, 20.45it/s]
# reading testing data
# 65it [00:00, 225.44it/s]
# done

# %%
print('X_train.shape: ' + str(X_train.shape))
print('Y_train.shape: ' + str(Y_train.shape))
print('X_test.shape: ' + str(X_test.shape))
print('length of sizes_test: ' + str(len(sizes_test)))
print(sizes_test[15])
# Out:
# X_train.shape: (670, 256, 256, 3)
# Y_train.shape: (670, 256, 256, 1)
# X_test.shape: (65, 256, 256, 3)
# length of sizes_test: 65
# (161, 519)

# %%
def get_contour(X, Y):
    '''
    :param images: images, ndarray, e.g.(500,256,256,3)
    :param labels: masks, ndarray, e.g.(500,256,256,1)
    :return:
    images with contour, e.g.(500,256,256,3)
    '''
    num_imgs = X.shape[0]
    contour_images = np.zeros((num_imgs, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
    contour_labels = np.zeros((num_imgs, IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    contours = np.zeros((num_imgs, IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    print('getting contours from masks...')
    sys.stdout.flush()
    for i in tqdm(range(0, num_imgs)):
        x = X[i]
        y = Y[i]
        c = imfilter(np.squeeze(y).astype(np.uint8), "find_edges")
#         c = c.astype(np.bool)
        c = np.expand_dims(c, axis=-1)
        contour_images[i] = x | c
        contour_labels[i] = y | c
        contours[i] = c
    print('Done!')
    return contour_images, contour_labels, contours

# %%
X_train_contour, Y_train_contour, contour = get_contour(X_train, Y_train)
# Out:
# getting contours from masks...
#   0%|          | 0/670 [00:00<?, ?it/s]/home/liming/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imfilter` is deprecated!
# `imfilter` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow filtering functionality directly.
# 100%|██████████| 670/670 [00:00<00:00, 948.72it/s]
# Done!

# %%
# save image information to pickle, when debugging, just read from pickle.
# import pickle
# output = open('dataset_info.pkl','wb')
# pickle.dump((X_train,Y_train,X_test,sizes_test,train_ids,test_ids,X_train_contour,Y_train_contour,contour),output)
# output.close()

# %%
# visualize data
def plot_train(X_train, Y_train, index = -1):
    if index == -1:
        index = np.random.randint(images.shape[0])
    image = X_train[index]
    label = Y_train[index]
    print('X_train(index = ' + str(index) + '):')
    plt.imshow(np.squeeze(image))
    plt.show()
    print('Y_train(index = ' + str(index) + '):')
    plt.imshow(np.squeeze(label), cmap ='gray')
    plt.show()
def plot_contour(X_train_contour, Y_train_contour, contour, index = -1):
    if index == -1:
        index = np.random.randint(images.shape[0])
    print('contour(index = ' + str(index) + '):')
    plt.imshow(np.squeeze(contour[index]), cmap ='gray')
    plt.show()
    print('X_train_contour(index = ' + str(index) + '):')
    plt.imshow(np.squeeze(X_train_contour[index]))
    plt.show()
    print('Y_train_contour(index = ' + str(index) + '):')
    plt.imshow(np.squeeze(Y_train_contour[index]), cmap ='gray')
    plt.show()

# %%
index +=1
idx = [idx for idx, train_id in enumerate(train_ids) if train_id == 'a102535b0e88374bea4a1cfd9ee7cb3822ff54f4ab2a9845d428ec22f9ee2288']
plot_train(X_train, Y_train, index)
# Out:
# X_train(index = 57):
# Y_train(index = 57):

# %%
# print(np.squeeze(contour[0]))
plot_contour(X_train_contour, Y_train_contour, contour, index = 11)

# %%
# data augmentation
def generator(xtr, xval, ytr, yval, batch_size):
    # training set augmentation
    data_gen_args = dict(horizontal_flip=True,
                         vertical_flip=True,
                         rotation_range=90.,
                         width_shift_range=0.1,
                         height_shift_range=0.1,
                         zoom_range=0.1)
    image_datagen = ImageDataGenerator(**data_gen_args)
    mask_datagen = ImageDataGenerator(**data_gen_args)
    # Provide the same seed and keyword arguments to the fit and flow methods
    image_datagen.fit(xtr, augment=True, seed=seed)
    mask_datagen.fit(ytr, augment=True, seed=seed)
    
    image_generator = image_datagen.flow(xtr, batch_size=batch_size, seed=seed)
    mask_generator = mask_datagen.flow(ytr, batch_size=batch_size, seed=seed)
    train_generator = zip(image_generator, mask_generator)
    
    # testing set augmentation
    val_gen_args = dict()
    image_datagen_val = ImageDataGenerator(**val_gen_args)
    mask_datagen_val = ImageDataGenerator(**val_gen_args)
    # Provide the same seed and keyword arguments to the fit and flow methods
    image_datagen_val.fit(xval,augment=True, seed=seed)
    mask_datagen_val.fit(yval,augment=True, seed=seed)
    image_generator_val = image_datagen.flow(xval, batch_size=batch_size, seed=seed)
    mask_generator_val = mask_datagen.flow(yval, batch_size=batch_size, seed=seed)
    val_generator = zip(image_generator_val, mask_generator_val)

    return train_generator, val_generator

# %%
# BATCH_SIZE = 16
# xtr, xval, ytr, yval = train_test_split(X_train, Y_train, test_size=0.1, random_state=7)
# train_generator, val_generator = generator(xtr, xval, ytr, yval, BATCH_SIZE)
# print(train_generator)

# %%
# for a,b in train_generator:
#     print(a.shape)
#     print(b.shape)
#     plt.imshow(a[0])
#     plt.show()
#     plt.imshow(np.squeeze(b[0]))
#     plt.show()
#     break

# %%
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec))

def dice_coef(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def bce_dice_loss(y_true, y_pred):
    return 0.5 * binary_crossentropy(y_true, y_pred) - dice_coef(y_true, y_pred)

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv1_1') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv1_2') (c1)
p1 = MaxPooling2D((2, 2), name = 'maxpool1') (c1)
print(c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv2_1') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv2_2') (c2)
p2 = MaxPooling2D((2, 2), name = 'maxpool2') (c2)
print(c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv3_1') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv3_2') (c3)
p3 = MaxPooling2D((2, 2), name = 'maxpool3') (c3)
print(c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv4_1') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv4_2') (c4)
p4 = MaxPooling2D(pool_size=(2, 2), name = 'maxpool4') (c4)
print(c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv5_1') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv5_2') (c5)
p5 = MaxPooling2D(pool_size=(2, 2), name = 'maxpool5') (c5)
print(c5)

c6 = Conv2D(512, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv6_1') (p5)
c6 = Dropout(0.3) (c6)
c6 = Conv2D(512, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv6_2') (c6)
print(c6)

u7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same', name = 'convT7') (c6)
u7 = concatenate([u7, c5])
c7 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv7_1') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv7_2') (c7)
print('c7:',c7)

u8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same', name = 'convT8') (c7)
u8 = concatenate([u8, c4])
c8 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv8_1') (u8)
c8 = Dropout(0.2) (c8)
c8 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv8_2') (c8)
print('c8:',c8)

u9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same', name = 'convT9') (c8)
u9 = concatenate([u9, c3])
c9 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv9_1') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv9_2') (c9)
print('c9:', c9)

u10 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same', name = 'conv10') (c9)
u10 = concatenate([u10, c2], axis=3)
c10 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv10_1') (u10)
c10 = Dropout(0.1) (c10)
c10 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv10_2') (c10)

u11 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same', name = 'conv11') (c10)
u11 = concatenate([u11, c1], axis=3)
c11 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv11_1') (u11)
c11 = Dropout(0.1) (c11)
c11 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same', name = 'conv11_2') (c11)


outputs = Conv2D(1, (1, 1), activation='sigmoid', name = 'conv12') (c11)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss=bce_dice_loss, metrics=[mean_iou])
model.summary()
# Out:
# Tensor("conv1_2/Elu:0", shape=(?, 256, 256, 16), dtype=float32)
# Tensor("conv2_2/Elu:0", shape=(?, 128, 128, 32), dtype=float32)
# Tensor("conv3_2/Elu:0", shape=(?, 64, 64, 64), dtype=float32)
# Tensor("conv4_2/Elu:0", shape=(?, 32, 32, 128), dtype=float32)
# Tensor("conv5_2/Elu:0", shape=(?, 16, 16, 256), dtype=float32)
# Tensor("conv6_2/Elu:0", shape=(?, 8, 8, 512), dtype=float32)
# c7: Tensor("conv7_2/Elu:0", shape=(?, 16, 16, 256), dtype=float32)
# c8: Tensor("conv8_2/Elu:0", shape=(?, 32, 32, 128), dtype=float32)
# c9: Tensor("conv9_2/Elu:0", shape=(?, 64, 64, 64), dtype=float32)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_1 (Conv2D)                (None, 256, 256, 16) 448         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 16) 0           conv1_1[0][0]
# __________________________________________________________________________________________________
# conv1_2 (Conv2D)                (None, 256, 256, 16) 2320        dropout_1[0][0]
# __________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)         (None, 128, 128, 16) 0           conv1_2[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv2D)                (None, 128, 128, 32) 4640        maxpool1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 128, 32) 0           conv2_1[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv2D)                (None, 128, 128, 32) 9248        dropout_2[0][0]
# __________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)         (None, 64, 64, 32)   0           conv2_2[0][0]
# __________________________________________________________________________________________________
# conv3_1 (Conv2D)                (None, 64, 64, 64)   18496       maxpool2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 64)   0           conv3_1[0][0]
# __________________________________________________________________________________________________
# conv3_2 (Conv2D)                (None, 64, 64, 64)   36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)         (None, 32, 32, 64)   0           conv3_2[0][0]
# __________________________________________________________________________________________________
# conv4_1 (Conv2D)                (None, 32, 32, 128)  73856       maxpool3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 128)  0           conv4_1[0][0]
# __________________________________________________________________________________________________
# conv4_2 (Conv2D)                (None, 32, 32, 128)  147584      dropout_4[0][0]
# __________________________________________________________________________________________________
# maxpool4 (MaxPooling2D)         (None, 16, 16, 128)  0           conv4_2[0][0]
# __________________________________________________________________________________________________
# conv5_1 (Conv2D)                (None, 16, 16, 256)  295168      maxpool4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 256)  0           conv5_1[0][0]
# __________________________________________________________________________________________________
# conv5_2 (Conv2D)                (None, 16, 16, 256)  590080      dropout_5[0][0]
# __________________________________________________________________________________________________
# maxpool5 (MaxPooling2D)         (None, 8, 8, 256)    0           conv5_2[0][0]
# __________________________________________________________________________________________________
# conv6_1 (Conv2D)                (None, 8, 8, 512)    1180160     maxpool5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 512)    0           conv6_1[0][0]
# __________________________________________________________________________________________________
# conv6_2 (Conv2D)                (None, 8, 8, 512)    2359808     dropout_6[0][0]
# __________________________________________________________________________________________________
# convT7 (Conv2DTranspose)        (None, 16, 16, 256)  524544      conv6_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 512)  0           convT7[0][0]
#                                                                  conv5_2[0][0]
# __________________________________________________________________________________________________
# conv7_1 (Conv2D)                (None, 16, 16, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 256)  0           conv7_1[0][0]
# __________________________________________________________________________________________________
# conv7_2 (Conv2D)                (None, 16, 16, 256)  590080      dropout_7[0][0]
# __________________________________________________________________________________________________
# convT8 (Conv2DTranspose)        (None, 32, 32, 128)  131200      conv7_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 256)  0           convT8[0][0]
#                                                                  conv4_2[0][0]
# __________________________________________________________________________________________________
# conv8_1 (Conv2D)                (None, 32, 32, 128)  295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 32, 32, 128)  0           conv8_1[0][0]
# __________________________________________________________________________________________________
# conv8_2 (Conv2D)                (None, 32, 32, 128)  147584      dropout_8[0][0]
# __________________________________________________________________________________________________
# convT9 (Conv2DTranspose)        (None, 64, 64, 64)   32832       conv8_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 128)  0           convT9[0][0]
#                                                                  conv3_2[0][0]
# __________________________________________________________________________________________________
# conv9_1 (Conv2D)                (None, 64, 64, 64)   73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64, 64, 64)   0           conv9_1[0][0]
# __________________________________________________________________________________________________
# conv9_2 (Conv2D)                (None, 64, 64, 64)   36928       dropout_9[0][0]
# __________________________________________________________________________________________________
# conv10 (Conv2DTranspose)        (None, 128, 128, 32) 8224        conv9_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 64) 0           conv10[0][0]
#                                                                  conv2_2[0][0]
# __________________________________________________________________________________________________
# conv10_1 (Conv2D)               (None, 128, 128, 32) 18464       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128, 128, 32) 0           conv10_1[0][0]
# __________________________________________________________________________________________________
# conv10_2 (Conv2D)               (None, 128, 128, 32) 9248        dropout_10[0][0]
# __________________________________________________________________________________________________
# conv11 (Conv2DTranspose)        (None, 256, 256, 16) 2064        conv10_2[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 256, 256, 32) 0           conv11[0][0]
#                                                                  conv1_2[0][0]
# __________________________________________________________________________________________________
# conv11_1 (Conv2D)               (None, 256, 256, 16) 4624        concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 256, 256, 16) 0           conv11_1[0][0]
# __________________________________________________________________________________________________
# conv11_2 (Conv2D)               (None, 256, 256, 16) 2320        dropout_11[0][0]
# __________________________________________________________________________________________________
# conv12 (Conv2D)                 (None, 256, 256, 1)  17          conv11_2[0][0]
# ==================================================================================================
# Total params: 7,775,601
# Trainable params: 7,775,601
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=BATCH_SIZE, epochs=75, 
                    callbacks=[earlystopper, checkpointer])
# model.fit_generator(train_generator, steps_per_epoch=len(xtr)/6, epochs=1, validation_data=val_generator, 
#                     validation_steps=len(xval)/BATCH_SIZE, verbose = 1, callbacks=[earlystopper, checkpointer])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/75
# 603/603 [==============================] - 22s 37ms/step - loss: -0.4580 - mean_iou: 0.5910 - val_loss: -0.7026 - val_mean_iou: 0.7032
#
# Epoch 00001: val_loss improved from inf to -0.70261, saving model to model-dsbowl2018.h5
# Epoch 2/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.7406 - mean_iou: 0.7387 - val_loss: -0.7479 - val_mean_iou: 0.7633
#
# Epoch 00002: val_loss improved from -0.70261 to -0.74788, saving model to model-dsbowl2018.h5
# Epoch 3/75
# 603/603 [==============================] - 18s 30ms/step - loss: -0.7691 - mean_iou: 0.7762 - val_loss: -0.7968 - val_mean_iou: 0.7889
#
# Epoch 00003: val_loss improved from -0.74788 to -0.79684, saving model to model-dsbowl2018.h5
# Epoch 4/75
# 603/603 [==============================] - 18s 30ms/step - loss: -0.7769 - mean_iou: 0.7960 - val_loss: -0.8252 - val_mean_iou: 0.8039
#
# Epoch 00004: val_loss improved from -0.79684 to -0.82523, saving model to model-dsbowl2018.h5
# Epoch 5/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8068 - mean_iou: 0.8106 - val_loss: -0.8382 - val_mean_iou: 0.8162
#
# Epoch 00005: val_loss improved from -0.82523 to -0.83821, saving model to model-dsbowl2018.h5
# Epoch 6/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8215 - mean_iou: 0.8213 - val_loss: -0.8282 - val_mean_iou: 0.8258
#
# Epoch 00006: val_loss did not improve
# Epoch 7/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8277 - mean_iou: 0.8296 - val_loss: -0.8474 - val_mean_iou: 0.8332
#
# Epoch 00007: val_loss improved from -0.83821 to -0.84739, saving model to model-dsbowl2018.h5
# Epoch 8/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8332 - mean_iou: 0.8363 - val_loss: -0.8401 - val_mean_iou: 0.8392
#
# Epoch 00008: val_loss did not improve
# Epoch 9/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8329 - mean_iou: 0.8414 - val_loss: -0.8497 - val_mean_iou: 0.8438
#
# Epoch 00009: val_loss improved from -0.84739 to -0.84970, saving model to model-dsbowl2018.h5
# Epoch 10/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8326 - mean_iou: 0.8458 - val_loss: -0.8367 - val_mean_iou: 0.8477
#
# Epoch 00010: val_loss did not improve
# Epoch 11/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8367 - mean_iou: 0.8495 - val_loss: -0.8495 - val_mean_iou: 0.8511
#
# Epoch 00011: val_loss did not improve
# Epoch 12/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8344 - mean_iou: 0.8526 - val_loss: -0.5842 - val_mean_iou: 0.8532
#
# Epoch 00012: val_loss did not improve
# Epoch 13/75
# 603/603 [==============================] - 18s 30ms/step - loss: -0.8413 - mean_iou: 0.8541 - val_loss: -0.8574 - val_mean_iou: 0.8555
#
# Epoch 00013: val_loss improved from -0.84970 to -0.85737, saving model to model-dsbowl2018.h5
# Epoch 14/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8443 - mean_iou: 0.8567 - val_loss: -0.8510 - val_mean_iou: 0.8579
#
# Epoch 00014: val_loss did not improve
# Epoch 15/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8442 - mean_iou: 0.8589 - val_loss: -0.8584 - val_mean_iou: 0.8600
#
# Epoch 00015: val_loss improved from -0.85737 to -0.85843, saving model to model-dsbowl2018.h5
# Epoch 16/75
# 603/603 [==============================] - 18s 30ms/step - loss: -0.8450 - mean_iou: 0.8610 - val_loss: -0.8597 - val_mean_iou: 0.8619
#
# Epoch 00016: val_loss improved from -0.85843 to -0.85974, saving model to model-dsbowl2018.h5
# Epoch 17/75
# 603/603 [==============================] - 18s 30ms/step - loss: -0.8497 - mean_iou: 0.8629 - val_loss: -0.8553 - val_mean_iou: 0.8637
#
# Epoch 00017: val_loss did not improve
# Epoch 18/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8483 - mean_iou: 0.8646 - val_loss: -0.8638 - val_mean_iou: 0.8654
#
# Epoch 00018: val_loss improved from -0.85974 to -0.86381, saving model to model-dsbowl2018.h5
# Epoch 19/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8510 - mean_iou: 0.8661 - val_loss: -0.8513 - val_mean_iou: 0.8668
#
# Epoch 00019: val_loss did not improve
# Epoch 20/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8556 - mean_iou: 0.8676 - val_loss: -0.8628 - val_mean_iou: 0.8682
#
# Epoch 00020: val_loss did not improve
# Epoch 21/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8442 - mean_iou: 0.8688 - val_loss: -0.8520 - val_mean_iou: 0.8692
#
# Epoch 00021: val_loss did not improve
# Epoch 22/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8497 - mean_iou: 0.8698 - val_loss: -0.8674 - val_mean_iou: 0.8703
#
# Epoch 00022: val_loss improved from -0.86381 to -0.86737, saving model to model-dsbowl2018.h5
# Epoch 23/75
# 603/603 [==============================] - 17s 29ms/step - loss: -0.8498 - mean_iou: 0.8709 - val_loss: -0.8525 - val_mean_iou: 0.8713
#
# Epoch 00023: val_loss did not improve
# Epoch 24/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8545 - mean_iou: 0.8719 - val_loss: -0.8629 - val_mean_iou: 0.8723
#
# Epoch 00024: val_loss did not improve
# Epoch 25/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8561 - mean_iou: 0.8729 - val_loss: -0.8644 - val_mean_iou: 0.8734
#
# Epoch 00025: val_loss did not improve
# Epoch 26/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8546 - mean_iou: 0.8738 - val_loss: -0.8689 - val_mean_iou: 0.8743
#
# Epoch 00026: val_loss improved from -0.86737 to -0.86893, saving model to model-dsbowl2018.h5
# Epoch 27/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8571 - mean_iou: 0.8747 - val_loss: -0.8653 - val_mean_iou: 0.8752
#
# Epoch 00027: val_loss did not improve
# Epoch 28/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8614 - mean_iou: 0.8756 - val_loss: -0.8589 - val_mean_iou: 0.8760
#
# Epoch 00028: val_loss did not improve
# Epoch 29/75
# 603/603 [==============================] - 18s 30ms/step - loss: -0.8620 - mean_iou: 0.8764 - val_loss: -0.8471 - val_mean_iou: 0.8769
#
# Epoch 00029: val_loss did not improve
# Epoch 30/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8602 - mean_iou: 0.8772 - val_loss: -0.8697 - val_mean_iou: 0.8776
#
# Epoch 00030: val_loss improved from -0.86893 to -0.86975, saving model to model-dsbowl2018.h5
# Epoch 31/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8627 - mean_iou: 0.8780 - val_loss: -0.8700 - val_mean_iou: 0.8784
#
# Epoch 00031: val_loss improved from -0.86975 to -0.87001, saving model to model-dsbowl2018.h5
# Epoch 32/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8629 - mean_iou: 0.8787 - val_loss: -0.8718 - val_mean_iou: 0.8791
#
# Epoch 00032: val_loss improved from -0.87001 to -0.87175, saving model to model-dsbowl2018.h5
# Epoch 33/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8627 - mean_iou: 0.8795 - val_loss: -0.8688 - val_mean_iou: 0.8798
#
# Epoch 00033: val_loss did not improve
# Epoch 34/75
# 603/603 [==============================] - 18s 30ms/step - loss: -0.8658 - mean_iou: 0.8802 - val_loss: -0.8711 - val_mean_iou: 0.8805
#
# Epoch 00034: val_loss did not improve
# Epoch 35/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8637 - mean_iou: 0.8808 - val_loss: -0.8685 - val_mean_iou: 0.8811
#
# Epoch 00035: val_loss did not improve
# Epoch 36/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8678 - mean_iou: 0.8814 - val_loss: -0.8658 - val_mean_iou: 0.8817
#
# Epoch 00036: val_loss did not improve
# Epoch 37/75
# 603/603 [==============================] - 18s 29ms/step - loss: -0.8634 - mean_iou: 0.8821 - val_loss: -0.8650 - val_mean_iou: 0.8823
#
# Epoch 00037: val_loss did not improve
# Epoch 00037: early stopping

# %%
# Predict on train, val and test
model = load_model('model-dsbowl2018.h5', custom_objects={'mean_iou': mean_iou, 'bce_dice_loss':bce_dice_loss,'dice_coef':dice_coef})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 603/603 [==============================] - 10s 17ms/step
# 67/67 [==============================] - 1s 11ms/step
# 65/65 [==============================] - 1s 10ms/step

# %%
# plot prediction
def plot_prediction(preds, preds_t, X, Y, index = -1):
    if index == -1:
        index = np.random.randint(0, X.shape[0]*0.9)
    print('image(index = ' + str(index) + '):')
    # print(np.squeeze(X_test[index]))
    plt.imshow(np.squeeze(X[index]))
    plt.show()
    if Y is not None:
        print('label(index = ' + str(index) + '):')
        plt.imshow(np.squeeze(Y[index]))
        plt.show()
    print('prediction: ')
    # print(np.squeeze(preds_test[index]))
    plt.imshow(np.squeeze(preds[index]), cmap = 'gray')
    plt.show()
    print('prediction (threshold>0.5): ')
    # print(np.squeeze(preds_test_t[index]))
    plt.imshow(np.squeeze(preds_t[index]), cmap = 'gray')
    plt.show()

# %%
# plot prediction on training set
plot_prediction(preds = preds_train, preds_t = preds_train_t, X = X_train, Y = Y_train, index=11)
# Out:
# image(index = 11):
# label(index = 11):
# prediction:
# prediction (threshold>0.5):

# %%
def pred_contour(idx):
    c = imfilter(np.squeeze(preds_train_t[idx]), "find_edges")
    c = c*255
    # convert one channel to three channel
    c = np.repeat(c[:,:,np.newaxis],3, axis=2)
    ax1, ax2, ax3 = np.where(c)
    overlay = X_train[idx]
    # make the overlay to yellow (255,255,0)
    overlay[ax1,ax2,0] = 255
    overlay[ax1,ax2,1] = 255
    overlay[ax1,ax2,2] = 0
    return overlay

# %%
overlay = pred_contour(11)
plt.imshow(overlay)
# Out:
# /home/liming/anaconda3/envs/tf/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imfilter` is deprecated!
# `imfilter` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow filtering functionality directly.

# %%
# plot prediction on testing set
plot_prediction(preds = preds_test, preds_t = preds_test_t, X = X_test, Y = None)
# Out:
# image(index = 55):
# prediction:
# prediction (threshold>0.5):

# %%
# plot prediction on testing set
index = np.random.randint(X_test.shape[0])
print('X_test(index = ' + str(index) + '):')
# print(np.squeeze(X_test[index]))
plt.imshow(np.squeeze(X_test[index]))
plt.show()
print('prediction on testing: ')
# print(np.squeeze(preds_test[index]))
plt.imshow(np.squeeze(preds_test[index]), cmap = 'gray')
plt.show()
print('prediction on testing (threshold>0.5): ')
# print(np.squeeze(preds_test_t[index]))
plt.imshow(np.squeeze(preds_test_t[index]), cmap = 'gray')
plt.show()
# Out:
# X_test(index = 29):
# prediction on testing:
# prediction on testing (threshold>0.5):

# %%
# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %%
print(preds_test_upsampled[0].shape)
print(test_ids[0])
# Out:
# (680, 512)
# da6c593410340b19bb212b9f6d274f95b08c0fc8f2570cd66bc5ed42c560acab

# %%
plt.imshow(preds_test_upsampled[0])

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids ):
    rle = list(prob_to_rles(preds_test_upsampled[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-4.csv', index=False)
