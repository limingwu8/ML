# %%
import dicom
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import scipy.ndimage
from skimage import measure, morphology
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
def get_files(file_dir):
    '''
    Args:
        file_dir: file directory
    Returns:
        list of file path
    '''
    dataset_path = []
    for root, dirs, files in os.walk(file_dir):
        for file in files:
            if not '.log' in file:
                dataset_path.append(os.path.join(root,file))
    return dataset_path

# %%
root = '/root/dataset/SCD_DeidentifiedImages/SCD0000101/1.32_29sSOG9riFiQfXpHFLC6Zj453OlBWiLWSxWS5LSwJbcf7neGtrQ_iHpfyZ7_KVjcy_-x_-y_64_64_158'
imgs = get_files(root)
imgs.sort()
imgs = imgs[:2]
slices = [dicom.read_file(img) for img in imgs]
fig = plt.figure(figsize=(5, 5))
fig.add_subplot(1,2,1)
plt.imshow(slices[0].pixel_array, cmap='gray')
fig.add_subplot(1,2,2)
plt.imshow(slices[1].pixel_array, cmap='gray')
plt.show()

# %%
root = '/root/dataset/SCD_DeidentifiedImages'
imgs = get_files(root)
slices = [dicom.read_file(img) for img in imgs[:72]]

# %%
IMG_PX_SIZE = 128
figure_size = 50

fig = plt.figure(figsize=(figure_size, figure_size))
for num,each_slice in enumerate(slices[:36]):
    y = fig.add_subplot(6,6,num+1)
#     new_img = cv2.resize(np.array(each_slice.pixel_array),(IMG_PX_SIZE,IMG_PX_SIZE))
    y.imshow(each_slice.pixel_array, cmap='gray')
plt.show()
